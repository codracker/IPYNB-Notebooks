# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split 
from sklearn.linear_model import LinearRegression
from sklearn import metrics
import matplotlib.pyplot as plt  
# %matplotlib inline

# %%
data=pd.read_csv('Advertising.csv')
data
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
X= data['TV'].values.reshape(-1,1)
y= data['Sales'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Tv')
plt.ylabel('Sales')
plt.show()

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_tv_sales=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:',rmse_tv_sales)
# Out:
# Root Mean Squared Error: 3.191579849311344

# %%
X= data['Radio'].values.reshape(-1,1)
y= data['Sales'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Radio')
plt.ylabel('Sales')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_rad_sales=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:',rmse_rad_sales)
# Out:
# Root Mean Squared Error: 4.923132441559148

# %%
X= data['Newspaper'].values.reshape(-1,1)
y= data['Sales'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Newspaper')
plt.ylabel('Sales')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_new_sales=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:',rmse_new_sales)
# Out:
# Root Mean Squared Error: 5.668963427559669

# %%
X= data['TV'].values.reshape(-1,1)
y= data['Radio'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Tv')
plt.ylabel('Radio')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_tv_rad = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:',rmse_tv_rad)
# Out:
# Root Mean Squared Error: 15.230946974527727

# %%
X= data['TV'].values.reshape(-1,1)
y= data['Newspaper'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Tv')
plt.ylabel('Newspaper')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test)
rmse_tv_news=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', rmse_tv_news)
# Out:
# Root Mean Squared Error: 23.54570051191129

# %%
X= data['Radio'].values.reshape(-1,1)
y= data['TV'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Radio')
plt.ylabel('TV')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test)
rmse_rad_tv=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', rmse_rad_tv)
# Out:
# Root Mean Squared Error: 89.3815797432113

# %%
X= data['Radio'].values.reshape(-1,1)
y= data['Newspaper'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Radio')
plt.ylabel('Newspaper')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_rad_news=np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:',rmse_rad_news )
# Out:
# Root Mean Squared Error: 20.74129567267591

# %%
X= data['Newspaper'].values.reshape(-1,1)
y= data['TV'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Newspaper')
plt.ylabel('Tv')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_news_tv =np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', rmse_news_tv)
# Out:
# Root Mean Squared Error: 91.57874382312255

# %%
X= data['Newspaper'].values.reshape(-1,1)
y= data['Radio'].values.reshape(-1,1)
plt.scatter(X, y, alpha=0.5)
plt.title('Scatter plot')
plt.xlabel('Newspaper')
plt.ylabel('Radio')
plt.show()
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)
regressor = LinearRegression()  
regressor.fit(X_train, y_train) 
y_pred = regressor.predict(X_test) 
rmse_news_rad = np.sqrt(metrics.mean_squared_error(y_test, y_pred))
print('Root Mean Squared Error:', rmse_news_rad)
# Out:
# Root Mean Squared Error: 13.676185115045566

# %%
print('The least RMSE value is of the TV and Sales and the values is',rmse_tv_sales)
# Out:
# The least RMSE value is of the TV and Sales and the values is 3.191579849311344
