# %%
import pandas as pd
import numpy as np
import warnings 
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("test.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Date     5 non-null      object
#  1   Life     5 non-null      object
#  2   DOB      5 non-null      object
#  3   DOB.1    5 non-null      object
#  4   Name     5 non-null      object
#  5   City     5 non-null      object
#  6   Country  5 non-null      object
# dtypes: object(7)
# memory usage: 408.0+ bytes

# %%
data.describe()
# Out:
#               Date        Life        DOB             DOB.1 Name City Country
# count            5           5          5                 5    5    5       5
# unique           5           5          5                 5    4    5       4
# top     27-06-2020  2020-05-27  29-Jun-90  28-06-1990 00:00    f    s       f
# freq             1           1          1                 1    2    1       2

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        try:
            data[col] = pd.to_datetime(data[col])
        except ValueError:
            pass

# %%
data.dtypes
# Out:
# Date       datetime64[ns]
# Life       datetime64[ns]
# DOB        datetime64[ns]
# DOB.1      datetime64[ns]
# Name               object
# City               object
# Country            object
# dtype: object

# %%
temp = data.select_dtypes(include=[np.datetime64])

# %%
temp
# Out:
#         Date       Life        DOB      DOB.1
# 0 2020-06-26 2020-05-25 1990-06-26 1990-06-26
# 1 2020-06-27 2020-05-26 1990-06-27 1990-06-27
# 2 2020-06-28 2020-05-27 1990-06-28 1990-06-28
# 3 2020-06-29 2020-05-28 1990-06-29 1990-06-29
# 4 2020-06-30 2020-05-29 1990-06-30 1990-06-30

# %%
n = len(temp.columns)
p = str(temp.columns[n-n]+ "-"+ temp.columns[n-(n-1)])
p
# Out:
# 'Date-Life'

# %%
n
# Out:
# 4

# %%
n = len(temp.columns)
i= 1
j=0
while i < n-1:
    p = str(temp.columns[j-j]+ "-"+ temp.columns[j+(i)])
    temp[p] = ((temp[temp.columns[n-n]])-(temp[temp.columns[n-(n+1)]]))
    i +=1

# %%
temp
# Out:
#         Date       Life        DOB      DOB.1   Date_DOB  Date_DOB1  \
# 0 2020-06-26 2020-05-25 1990-06-26 1990-06-26 10958 days 10958 days
# 1 2020-06-27 2020-05-26 1990-06-27 1990-06-27 10958 days 10958 days
# 2 2020-06-28 2020-05-27 1990-06-28 1990-06-28 10958 days 10958 days
# 3 2020-06-29 2020-05-28 1990-06-29 1990-06-29 10958 days 10958 days
# 4 2020-06-30 2020-05-29 1990-06-30 1990-06-30 10958 days 10958 days
#
#     Date-DOB Date-Date_DOB Date-Date-DOB Date-Date-Date-DOB  Date-Life  \
# 0 2020-05-25    2020-05-25    2020-05-25            32 days 2020-05-25
# 1 2020-05-26    2020-05-26    2020-05-26            32 days 2020-05-26
# 2 2020-05-27    2020-05-27    2020-05-27            32 days 2020-05-27
# 3 2020-05-28    2020-05-28    2020-05-28            32 days 2020-05-28
# 4 2020-05-29    2020-05-29    2020-05-29            32 days 2020-05-29
#
#   Date-DOB.1 Date-Date_DOB1 Date-Date-Date_DOB Date-Date-Date-Date-DOB  \
# ...

# %%
Date_DOB = temp['Date']-temp['DOB']
temp['Date_DOB'] = Date_DOB
Date_DOB1 = temp['Date']-temp['DOB.1']
temp['Date_DOB1'] = Date_DOB1
temp['Date_DOB'] = Date_DOB

# %%
temp
# Out:
#         Date       Life        DOB      DOB.1   Date_DOB  Date_DOB1  \
# 0 2020-06-26 2020-05-25 1990-06-26 1990-06-26 10958 days 10958 days
# 1 2020-06-27 2020-05-26 1990-06-27 1990-06-27 10958 days 10958 days
# 2 2020-06-28 2020-05-27 1990-06-28 1990-06-28 10958 days 10958 days
# 3 2020-06-29 2020-05-28 1990-06-29 1990-06-29 10958 days 10958 days
# 4 2020-06-30 2020-05-29 1990-06-30 1990-06-30 10958 days 10958 days
#
#     Date-DOB Date-Date_DOB Date-Date-DOB Date-Date-Date-DOB  Date-Life  \
# 0 2020-05-25    2020-05-25    2020-05-25            32 days 2020-05-25
# 1 2020-05-26    2020-05-26    2020-05-26            32 days 2020-05-26
# 2 2020-05-27    2020-05-27    2020-05-27            32 days 2020-05-27
# 3 2020-05-28    2020-05-28    2020-05-28            32 days 2020-05-28
# 4 2020-05-29    2020-05-29    2020-05-29            32 days 2020-05-29
#
#   Date-DOB.1 Date-Date_DOB1 Date-Date-Date_DOB Date-Date-Date-Date-DOB  \
# ...
