# %%
import pandas as pd
import numpy as np
import datetime

# %%
pd.read_csv("WALM")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-31-9de1c29c736a> in <module>
# ----> 1 pd.read_csv("WALM")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     700                     skip_blank_lines=skip_blank_lines)
#     701
# ...

# %%
data=pd.read_csv("WALM.csv", index_col="Series")

# %%
data
# Out:
#        Symbol         Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL  15-May-2017      994.50      995.10     1008.00     995.10
# EQ        IGL  16-May-2017     1000.25     1007.60     1009.00     988.50
# EQ        IGL  17-May-2017     1005.80     1009.00     1027.00    1008.90
# EQ        IGL  18-May-2017     1019.10     1019.10     1019.10     999.10
# EQ        IGL  19-May-2017     1002.55     1005.00     1010.85     993.00
# EQ        IGL  22-May-2017     1000.15     1002.00     1007.55     979.30
# EQ        IGL  23-May-2017      987.20      988.50      995.50     966.80
# EQ        IGL  24-May-2017      981.45      981.45      988.90     971.20
# EQ        IGL  25-May-2017      982.65      990.70      992.60     967.80
# EQ        IGL  26-May-2017      984.45      986.00     1032.95     985.15
# EQ        IGL  29-May-2017     1026.05     1034.00     1048.90    1010.40
# EQ        IGL  30-May-2017     1026.05     1027.20     1064.90    1022.90
# ...

# %%
data.head()
# Out:
#        Symbol         Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL  15-May-2017      994.50       995.1     1008.00      995.1
# EQ        IGL  16-May-2017     1000.25      1007.6     1009.00      988.5
# EQ        IGL  17-May-2017     1005.80      1009.0     1027.00     1008.9
# EQ        IGL  18-May-2017     1019.10      1019.1     1019.10      999.1
# EQ        IGL  19-May-2017     1002.55      1005.0     1010.85      993.0
#
#             Last Price  Close Price  Average Price  Total Traded Quantity  \
# Series
# EQ             1002.00      1000.25        1001.54                 314597
# EQ             1006.00      1005.80         998.30                 178249
# EQ             1019.65      1019.10        1020.26                 337329
# EQ             1000.05      1002.55        1008.46                 168584
# EQ             1002.60      1000.15        1001.42                 149678
#
# ...

# %%
data2=data.drop("IL")

# %%
data2
# Out:
#        Symbol         Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL  15-May-2017      994.50      995.10     1008.00     995.10
# EQ        IGL  16-May-2017     1000.25     1007.60     1009.00     988.50
# EQ        IGL  17-May-2017     1005.80     1009.00     1027.00    1008.90
# EQ        IGL  18-May-2017     1019.10     1019.10     1019.10     999.10
# EQ        IGL  19-May-2017     1002.55     1005.00     1010.85     993.00
# EQ        IGL  22-May-2017     1000.15     1002.00     1007.55     979.30
# EQ        IGL  23-May-2017      987.20      988.50      995.50     966.80
# EQ        IGL  24-May-2017      981.45      981.45      988.90     971.20
# EQ        IGL  25-May-2017      982.65      990.70      992.60     967.80
# EQ        IGL  26-May-2017      984.45      986.00     1032.95     985.15
# EQ        IGL  29-May-2017     1026.05     1034.00     1048.90    1010.40
# EQ        IGL  30-May-2017     1026.05     1027.20     1064.90    1022.90
# ...

# %%
max=data2.max[404:]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-37-120d9bf1fea7> in <module>
# ----> 1 max=data2.max[404:]
#
# TypeError: 'method' object is not subscriptable

# %%
shape=data2.shape

# %%
shape
# Out:
# (494, 14)

# %%
data2=data2[404:]
data2
# Out:
#        Symbol         Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL  31-Dec-2018      265.10      265.00      268.00     262.60
# EQ        IGL  01-Jan-2019      267.25      268.00      274.50     267.15
# EQ        IGL  02-Jan-2019      271.65      271.60      276.75     269.85
# EQ        IGL  03-Jan-2019      275.35      275.25      276.00     272.10
# EQ        IGL  04-Jan-2019      274.30      273.50      279.75     273.00
# EQ        IGL  07-Jan-2019      278.05      279.95      280.00     272.00
# EQ        IGL  08-Jan-2019      273.55      273.90      274.90     270.00
# EQ        IGL  09-Jan-2019      270.55      272.95      273.00     265.10
# EQ        IGL  10-Jan-2019      266.20      265.80      268.00     265.25
# EQ        IGL  11-Jan-2019      266.50      268.70      271.55     265.15
# EQ        IGL  14-Jan-2019      270.75      268.55      273.10     266.45
# EQ        IGL  15-Jan-2019      271.65      271.05      274.80     269.35
# ...

# %%
data2.shape
# Out:
# (90, 14)

# %%
max_price=max(data2["Close Price"])
max_price
# Out:
# 327.2

# %%
min_price=min(data2["Close Price"])

# %%
min_price
# Out:
# 266.2

# %%
mean_price=np.mean(data2["Close Price"])
mean_price
# Out:
# 293.27166666666665

# %%
data2["Date"]=data2["Date"].typeas["datetime64(ns)"]
data2
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-ea6d7a774aa5> in <module>
# ----> 1 data2["Date"]=data2["Date"].typeas["datetime64(ns)"]
#       2 data2
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'typeas'

# %%
data2.describe()
# Out:
#        Prev Close  Open Price  High Price   Low Price  Close Price  \
# count   90.000000   90.000000   90.000000   90.000000    90.000000
# mean   292.926111  293.183333  297.745556  288.965000   293.271667
# std     15.800013   15.793721   16.022571   15.859353    15.522248
# min    265.100000  265.000000  268.000000  257.600000   266.200000
# 25%    280.862500  281.125000  284.850000  275.475000   282.100000
# 50%    291.300000  293.000000  299.625000  288.900000   291.775000
# 75%    307.162500  307.937500  311.700000  304.262500   307.162500
# max    327.200000  324.000000  329.750000  320.050000   327.200000
#
#        Average Price  Total Traded Quantity      Turnover  No. of Trades  \
# count      90.000000           9.000000e+01  9.000000e+01      90.000000
# mean      293.518333           2.065663e+06  6.062700e+08   29701.066667
# std        15.936770           1.356433e+06  3.975936e+08   19215.894183
# ...

# %%
data_type=data2.dtypes
data_type
# Out:
# Symbol                     object
# Date                       object
# Prev Close                float64
# Open Price                float64
# High Price                float64
# Low Price                 float64
# Last Price                 object
# Close Price               float64
# Average Price             float64
# Total Traded Quantity       int64
# Turnover                  float64
# No. of Trades               int64
# Deliverable Qty             int64
# % Dly Qt to Traded Qty    float64
# dtype: object

# %%
data2['Date'] = data2['Date'].astype('datetime64[ns]')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data2['Date']
# Out:
# Series
# EQ   2018-12-31
# EQ   2019-01-01
# EQ   2019-01-02
# EQ   2019-01-03
# EQ   2019-01-04
# EQ   2019-01-07
# EQ   2019-01-08
# EQ   2019-01-09
# EQ   2019-01-10
# EQ   2019-01-11
# EQ   2019-01-14
# EQ   2019-01-15
# EQ   2019-01-16
# EQ   2019-01-17
# EQ   2019-01-18
# EQ   2019-01-21
# EQ   2019-01-22
# EQ   2019-01-23
# EQ   2019-01-24
# EQ   2019-01-25
# EQ   2019-01-28
# EQ   2019-01-29
# EQ   2019-01-30
# EQ   2019-01-31
# EQ   2019-02-01
# EQ   2019-02-04
# EQ   2019-02-05
# EQ   2019-02-06
# EQ   2019-02-07
# EQ   2019-02-08
#         ...
# EQ   2019-03-27
# EQ   2019-03-28
# EQ   2019-03-29
# EQ   2019-04-01
# EQ   2019-04-02
# EQ   2019-04-03
# EQ   2019-04-04
# EQ   2019-04-05
# EQ   2019-04-08
# EQ   2019-04-09
# EQ   2019-04-10
# EQ   2019-04-11
# EQ   2019-04-12
# EQ   2019-04-15
# EQ   2019-04-16
# EQ   2019-04-18
# EQ   2019-04-22
# EQ   2019-04-23
# EQ   2019-04-24
# EQ   2019-04-25
# EQ   2019-04-26
# EQ   2019-04-30
# EQ   2019-05-02
# EQ   2019-05-03
# ...

# %%
diff=max(data2['Date'])-min(data2['Date'])
diff
# Out:
# Timedelta('133 days 00:00:00')

# %%
data2['Month']=pd.DatetimeIndex(data2['Date']).month
data2['Year'] =pd.DatetimeIndex(data2['Date']).year
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data2
# Out:
#        Symbol       Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL 2018-12-31      265.10      265.00      268.00     262.60
# EQ        IGL 2019-01-01      267.25      268.00      274.50     267.15
# EQ        IGL 2019-01-02      271.65      271.60      276.75     269.85
# EQ        IGL 2019-01-03      275.35      275.25      276.00     272.10
# EQ        IGL 2019-01-04      274.30      273.50      279.75     273.00
# EQ        IGL 2019-01-07      278.05      279.95      280.00     272.00
# EQ        IGL 2019-01-08      273.55      273.90      274.90     270.00
# EQ        IGL 2019-01-09      270.55      272.95      273.00     265.10
# EQ        IGL 2019-01-10      266.20      265.80      268.00     265.25
# EQ        IGL 2019-01-11      266.50      268.70      271.55     265.15
# EQ        IGL 2019-01-14      270.75      268.55      273.10     266.45
# EQ        IGL 2019-01-15      271.65      271.05      274.80     269.35
# ...

# %%
data2_group=data2.groupby(['Month'])

# %%
data2_group.head()
# Out:
#        Symbol       Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL 2018-12-31      265.10      265.00      268.00     262.60
# EQ        IGL 2019-01-01      267.25      268.00      274.50     267.15
# EQ        IGL 2019-01-02      271.65      271.60      276.75     269.85
# EQ        IGL 2019-01-03      275.35      275.25      276.00     272.10
# EQ        IGL 2019-01-04      274.30      273.50      279.75     273.00
# EQ        IGL 2019-01-07      278.05      279.95      280.00     272.00
# EQ        IGL 2019-02-01      283.55      283.55      289.85     283.55
# EQ        IGL 2019-02-04      286.90      283.65      299.35     283.65
# EQ        IGL 2019-02-05      294.70      295.95      311.40     294.75
# EQ        IGL 2019-02-06      305.55      303.00      305.00     297.25
# EQ        IGL 2019-02-07      299.70      296.00      309.40     292.60
# EQ        IGL 2019-03-01      292.80      293.00      296.05     290.75
# ...

# %%
data2['VWAP']= (np.cumsum(data2['Total Traded Quantity']*data2['Close Price']) / np.cumsum(data2['Total Traded Quantity']))
data2vwap_group=data2.groupby(['Month','VWAP'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
data2vwap_group.head()
# Out:
#        Symbol       Date  Prev Close  Open Price  High Price  Low Price  \
# Series
# EQ        IGL 2018-12-31      265.10      265.00      268.00     262.60
# EQ        IGL 2019-01-01      267.25      268.00      274.50     267.15
# EQ        IGL 2019-01-02      271.65      271.60      276.75     269.85
# EQ        IGL 2019-01-03      275.35      275.25      276.00     272.10
# EQ        IGL 2019-01-04      274.30      273.50      279.75     273.00
# EQ        IGL 2019-01-07      278.05      279.95      280.00     272.00
# EQ        IGL 2019-01-08      273.55      273.90      274.90     270.00
# EQ        IGL 2019-01-09      270.55      272.95      273.00     265.10
# EQ        IGL 2019-01-10      266.20      265.80      268.00     265.25
# EQ        IGL 2019-01-11      266.50      268.70      271.55     265.15
# EQ        IGL 2019-01-14      270.75      268.55      273.10     266.45
# EQ        IGL 2019-01-15      271.65      271.05      274.80     269.35
# ...
