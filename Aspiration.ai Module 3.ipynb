# %%
import pandas as pd 
gold_data= pd.read_csv('GOLD.csv')
gold_data
# Out:
#              Date  Price   Open   High    Low    Vol. Change %   Pred  \
# 0    May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0
# 1    May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0
# 2    May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0
# 3    May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0
# 4    May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0
# 5    May 11, 2017  28022  27995  28100  27945   9.72K    0.05%  149.0
# 6    May 12, 2017  28019  28088  28195  27985   9.48K   -0.01%  167.0
# 7    May 15, 2017  28008  28049  28157  27996   8.76K   -0.04%   22.0
# 8    May 16, 2017  28109  28025  28159  28025   7.73K    0.36%   34.0
# 9    May 17, 2017  28614  28170  28638  28170  15.92K    1.80%  420.0
# 10   May 18, 2017  28710  28666  28980  28551  23.80K    0.34%  234.0
# 11   May 19, 2017  28634  28660  28779  28531  13.16K   -0.26%  345.0
# ...

# %%
gold_data.set_index('Date',inplace=True)
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %   Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0  112.153318
# May 11, 2017  28022  27995  28100  27945   9.72K    0.05%  149.0  182.427089
# May 12, 2017  28019  28088  28195  27985   9.48K   -0.01%  167.0  141.255137
# May 15, 2017  28008  28049  28157  27996   8.76K   -0.04%   22.0  120.069010
# May 16, 2017  28109  28025  28159  28025   7.73K    0.36%   34.0  218.401641
# May 17, 2017  28614  28170  28638  28170  15.92K    1.80%  420.0  919.376358
# May 18, 2017  28710  28666  28980  28551  23.80K    0.34%  234.0  475.389093
# ...

# %%
gold_data_without_nan=gold_data.dropna()
gold_data_without_nan
# Out:
#               Price   Open   High    Low    Vol. Change %   Pred          new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%  738.0   117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44% -146.0   295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   30.0   132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%  357.0   101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%  124.0   112.153318
# May 11, 2017  28022  27995  28100  27945   9.72K    0.05%  149.0   182.427089
# May 12, 2017  28019  28088  28195  27985   9.48K   -0.01%  167.0   141.255137
# May 15, 2017  28008  28049  28157  27996   8.76K   -0.04%   22.0   120.069010
# May 16, 2017  28109  28025  28159  28025   7.73K    0.36%   34.0   218.401641
# May 17, 2017  28614  28170  28638  28170  15.92K    1.80%  420.0   919.376358
# May 18, 2017  28710  28666  28980  28551  23.80K    0.34%  234.0   475.389093
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
y = np.array(gold_data_without_nan["Pred"])
x = np.array(gold_data_without_nan["new"])
x = x.reshape(-1,1)
y = y.reshape(-1,1)
regressor = LinearRegression()
regressor.fit(x, y)             # training the model
y_predicted = regressor.predict(x)
rmse = mean_squared_error(y, y_predicted)
r2 = r2_score(y, y_predicted)
print('Slope:' ,regressor.coef_)
print('Intercept:', regressor.intercept_)
print('Root mean squared error: ', rmse)
print('R2 score: ', r2)
plt.scatter(x, y, s=10)
plt.xlabel('x')
plt.ylabel('y')
plt.plot(x, y_predicted, color='r')
plt.show()
# Out:
# Slope: [[-0.00823083]]
# Intercept: [343.67028421]
# Root mean squared error:  73300.46132887459
# R2 score:  3.732507600850976e-05

# %%
pre_data = gold_data[:]
pre_data_new = pre_data['new']
pre_data_new = pre_data_new.values.reshape(-1,1)

# %%
na_data = (regressor.predict(pre_data_new))#getting predicted values
na_data_series = pd.Series(na_data.ravel())
sata = na_data_series.to_frame()
gold_data['Pred'] = sata
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %  Pred         new
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%   NaN  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44%   NaN  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   NaN  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%   NaN  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%   NaN  112.153318
# May 11, 2017  28022  27995  28100  27945   9.72K    0.05%   NaN  182.427089
# May 12, 2017  28019  28088  28195  27985   9.48K   -0.01%   NaN  141.255137
# May 15, 2017  28008  28049  28157  27996   8.76K   -0.04%   NaN  120.069010
# May 16, 2017  28109  28025  28159  28025   7.73K    0.36%   NaN  218.401641
# May 17, 2017  28614  28170  28638  28170  15.92K    1.80%   NaN  919.376358
# May 18, 2017  28710  28666  28980  28551  23.80K    0.34%   NaN  475.389093
# ...

# %%
na_data = (regressor.predict(gold_data_new))

# %%
na_data
# Out:
# array([[342.70257957],
#        [341.238649  ],
#        [342.58279653],
#        [342.83651718],
#        [342.74716944],
#        [342.16875806],
#        [342.50763735],
#        [342.68201674],
#        [341.87265768],
#        [336.10305478],
#        [339.75743795],
#        [341.83567109],
#        [340.16610362],
#        [342.06980326],
#        [343.09997826],
#        [343.34742275],
#        [340.82111366],
#        [342.41688187],
#        [343.14981343],
#        [339.16706918],
#        [343.36399343],
#        [338.74738789],
#        [342.01336268],
#        [339.17158548],
#        [342.74518791],
#        [342.63868396],
#        [342.75985623],
#        [342.58155532],
#        [342.34447746],
#        [341.36470623],
#        [343.2883611 ],
#        [343.36520019],
#        [343.56278339],
#        [342.72198673],
#        [342.61215252],
#        [342.20354064],
#        [341.70856304],
#        [341.19273251],
#        [341.66612912],
#        [342.72235769],
# ...

# %%
na_data_series = pd.Series(na_data.ravel())
na_data_series
# Out:
# 0      342.702580
# 1      341.238649
# 2      342.582797
# 3      342.836517
# 4      342.747169
# 5      342.168758
# 6      342.507637
# 7      342.682017
# 8      341.872658
# 9      336.103055
# 10     339.757438
# 11     341.835671
# 12     340.166104
# 13     342.069803
# 14     343.099978
# 15     343.347423
# 16     340.821114
# 17     342.416882
# 18     343.149813
# 19     339.167069
# 20     343.363993
# 21     338.747388
# 22     342.013363
# 23     339.171585
# 24     342.745188
# 25     342.638684
# 26     342.759856
# 27     342.581555
# 28     342.344477
# 29     341.364706
#           ...
# 482    342.013484
# 483    337.681620
# 484    342.133532
# 485    342.991795
# 486    342.846312
# 487    343.090352
# 488    340.520323
# 489    342.269670
# 490    341.881754
# 491    341.684859
# 492    341.991432
# 493    341.594773
# 494    338.368135
# 495    342.696019
# 496    340.917272
# 497    343.461196
# 498    341.980594
# 499    341.428782
# 500    342.936009
# ...

# %%
sata = na_data_series.to_frame()
sata
# Out:
#               0
# 0    342.702580
# 1    341.238649
# 2    342.582797
# 3    342.836517
# 4    342.747169
# 5    342.168758
# 6    342.507637
# 7    342.682017
# 8    341.872658
# 9    336.103055
# 10   339.757438
# 11   341.835671
# 12   340.166104
# 13   342.069803
# 14   343.099978
# 15   343.347423
# 16   340.821114
# 17   342.416882
# 18   343.149813
# 19   339.167069
# 20   343.363993
# 21   338.747388
# 22   342.013363
# 23   339.171585
# 24   342.745188
# 25   342.638684
# 26   342.759856
# 27   342.581555
# 28   342.344477
# 29   341.364706
# ..          ...
# 482  342.013484
# 483  337.681620
# 484  342.133532
# 485  342.991795
# 486  342.846312
# 487  343.090352
# 488  340.520323
# 489  342.269670
# 490  341.881754
# 491  341.684859
# 492  341.991432
# 493  341.594773
# 494  338.368135
# 495  342.696019
# 496  340.917272
# 497  343.461196
# 498  341.980594
# 499  341.428782
# 500  342.936009
# 501  343.324001
# 502  342.696665
# 503  341.742493
# 504  342.018755
# ...

# %%
gold_data['Pred'] = sata

# %%
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %  Pred         new  \
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%   NaN  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44%   NaN  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   NaN  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%   NaN  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%   NaN  112.153318
# May 11, 2017  28022  27995  28100  27945   9.72K    0.05%   NaN  182.427089
# May 12, 2017  28019  28088  28195  27985   9.48K   -0.01%   NaN  141.255137
# May 15, 2017  28008  28049  28157  27996   8.76K   -0.04%   NaN  120.069010
# May 16, 2017  28109  28025  28159  28025   7.73K    0.36%   NaN  218.401641
# May 17, 2017  28614  28170  28638  28170  15.92K    1.80%   NaN  919.376358
# May 18, 2017  28710  28666  28980  28551  23.80K    0.34%   NaN  475.389093
# ...

# %%
gold_data
# Out:
#               Price   Open   High    Low    Vol. Change %  Pred         new  \
# Date
# May 04, 2017  28060  28400  28482  28025   0.08K   -1.79%   NaN  117.570740
# May 05, 2017  28184  28136  28382  28135   0.06K    0.44%   NaN  295.430176
# May 08, 2017  28119  28145  28255  28097   7.85K   -0.23%   NaN  132.123714
# May 09, 2017  27981  28125  28192  27947  10.10K   -0.49%   NaN  101.298064
# May 10, 2017  28007  28060  28146  27981   9.28K    0.09%   NaN  112.153318
# May 11, 2017  28022  27995  28100  27945   9.72K    0.05%   NaN  182.427089
# May 12, 2017  28019  28088  28195  27985   9.48K   -0.01%   NaN  141.255137
# May 15, 2017  28008  28049  28157  27996   8.76K   -0.04%   NaN  120.069010
# May 16, 2017  28109  28025  28159  28025   7.73K    0.36%   NaN  218.401641
# May 17, 2017  28614  28170  28638  28170  15.92K    1.80%   NaN  919.376358
# May 18, 2017  28710  28666  28980  28551  23.80K    0.34%   NaN  475.389093
# ...
